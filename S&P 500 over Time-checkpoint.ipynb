# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import statsmodels.api as sm
df = pd.read_csv("data - data (4).csv")

df.head()
# Out:
#          Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 0  1871-01-01   4.44      0.26       0.4                 12.46
# 1  1871-02-01   4.50      0.26       0.4                 12.84
# 2  1871-03-01   4.61      0.26       0.4                 13.03
# 3  1871-04-01   4.74      0.26       0.4                 12.56
# 4  1871-05-01   4.86      0.26       0.4                 12.27
#
#    Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10    Year  \
# 0                5.32       89.00           5.21           8.02   NaN  1871.0
# 1                5.32       87.53           5.06           7.78   NaN  1872.0
# 2                5.33       88.36           4.98           7.67   NaN  1873.0
# 3                5.33       94.29           5.17           7.96   NaN  1874.0
# 4                5.33       98.93           5.29           8.14   NaN  1875.0
#
#    Real Price Year-by-Year   Yearly Percentage Change
# 0                     93.58                  0.000000
# ...

# %%
time_percent = df.groupby("Year")[["Yearly Percentage Change"]]
plt.plot(df["Year"], df["Yearly Percentage Change"])

plt.title("Time and S&P 500 performance")
plt.ylabel("S&P 500 yearly Percetage Change")
plt.xlabel("Decades")
# Out:
# Text(0.5, 0, 'Decades')

# %%
time_percent = df.groupby("Year")[["Yearly Percentage Change"]]
plt.scatter(df["Year"], df["Yearly Percentage Change"], color = "blue")

# %%
time_percent = df.groupby("Year")[["Yearly Percentage Change"]]
plt.scatter(df["Year"], df["Yearly Percentage Change"], color = "blue")

# %%
time_percent = df.groupby("Year")[["Yearly Percentage Change"]]
plt.plot(df["Year"], df["Yearly Percentage Change"])
time_inf = df.groupby("Year")[["Yearly Percentage Change"]]
plt.plot(df["Year"], df["Yearly Percentage Change"])

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 new_data = pd.read_csv("S&P 500 VS CPI Fuel Oil - Sheet1 (3).csv")
#
# File ~\miniconda3\Miniconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
