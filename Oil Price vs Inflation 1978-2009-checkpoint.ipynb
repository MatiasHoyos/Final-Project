# %%
#importing libraries import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import statsmodels.api as sm
df = pd.read_csv("AAAA.csv") #reading the file containing the data
df.head() #prints information
# Out:
#    Year  Average Percentage Change  Unnamed: 2  Year 2  \
# 0  1978                   0.000000         NaN    1978
# 1  1979                  35.276819         NaN    1979
# 2  1980                  38.516068         NaN    1980
# 3  1981                  10.774480         NaN    1981
# 4  1982                  -5.328323         NaN    1982
#
#    Average Percentage Change Inflation  Inflation  Unnamed: 6
# 0                             0.000000       6.84    0.000000
# 1                            35.672515       9.28   35.672515
# 2                            49.892241      13.91   49.892241
# 3                           -14.953271      11.83  -14.953271
# 4                           -29.078614       8.39  -29.078614

# %%
import matplotlib
matplotlib.style.use("Solarize_Light2")
matplotlib.rcParams["font.family"] = "MS Times New Roman" #despite trying to change the font multiple times it didnt read the fonts

# %%
#labels
plt.ylabel("percentage change")
plt.xlabel("Time")
plt.title("Fuel Oil Prices (purple), and Inflation Yearly percentage change")

#assigning variables and actually plotting the data
time_percent = df.groupby("Year")[["Average Percentage Change"]]
plt.plot(df["Year"], df["Average Percentage Change"], color = "purple" )
time_inf = df.groupby("Year 2")[["Average Percentage Change Inflation"]]
plt.plot(df["Year 2"], df["Average Percentage Change Inflation"])
#changing colors for graph
plt.grid(True, color = "DarkGrey", linewidth = "0.5", linestyle = "-")
