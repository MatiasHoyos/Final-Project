# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import statsmodels.api as sm
df = pd.read_csv("AAA.csv") #reading the file containing the data
df.head()
# Out:
#    Year  Average Percentage Change  Unnamed: 2  Year 2     S&P500
# 0  1978                   0.000000         NaN    1978  -6.032587
# 1  1979                  35.276819         NaN    1979  -0.998083
# 2  1980                  38.516068         NaN    1980  10.064362
# 3  1981                  10.774480         NaN    1981 -14.862347
# 4  1982                  -5.328323         NaN    1982   8.445782

# %%
import matplotlib
matplotlib.style.use("Solarize_Light2")
matplotlib.rcParams["font.family"] = "MS Times New Roman" #despite trying to change the font multiple times it didnt read the fonts

# %%
#labels
plt.ylabel("percentage change")
plt.xlabel("Time")
plt.title("Fuel Oil Prices (blue), and S&P 500 Yearly percentage change")

#assigning variables and actually plotting the data
time_percent = df.groupby("Year")[["Average Percentage Change"]]
plt.plot(df["Year"], df["Average Percentage Change"])
time_inf = df.groupby("Year 2")[["S&P500"]]
plt.plot(df["Year 2"], df["S&P500"])

#changing colors for graph
plt.grid(True, color = "DarkGrey", linewidth = "0.5", linestyle = "-")
# Out:
# findfont: Font family ['MS Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['MS Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['MS Times New Roman'] not found. Falling back to DejaVu Sans.
